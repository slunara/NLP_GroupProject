# %% [markdown]
# <a href="https://colab.research.google.com/github/slunara/NLP_GroupProject/blob/main/run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NLP Group project

# %% [markdown]
# Clone the repo

# %%
import os
import shutil

# Define repository details
repo_url = "https://github.com/slunara/NLP_GroupProject.git"
repo_dir = "/content/NLP_GroupProject"

# Check if the repository already exists
if os.path.exists(repo_dir):
    # If it exists, pull the latest changes
    print("Repository already exists. Pulling the latest changes...")
    # %cd $repo_dir
    # !git reset --hard  # Reset any local changes
    # !git pull origin main
else:
    # If it doesn't exist, clone the repository
    print("Cloning the repository...")
    # !git clone $repo_url $repo_dir

# Change to the repository directory
# %cd $repo_dir

# Install dependencies
print("Installing dependencies...")
# !pip install -r requirements.txt
# Out:
# Repository already exists. Pulling the latest changes...
# /content
# HEAD is now at 19ff465 Update platemate.py
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1.06 KiB | 1.06 MiB/s, done.
# From https://github.com/slunara/NLP_GroupProject
#  * branch            main       -> FETCH_HEAD
#    19ff465..d1f3d7d  main       -> origin/main
# Updating 19ff465..d1f3d7d
# Fast-forward
#  platemate.py | 26 +++++++++++++-------------
#  1 file changed, 13 insertions(+), 13 deletions(-)
# /content
# Installing dependencies...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 63.2 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/amaiya/eli5 (to revision tfkeras_0_10_1) to /tmp/pip-req-build-ihfwpzr7
# ...

# %%
# !rm -rf ./tmp/myindex*

# %% [markdown]
# Run the application
#
# Test it with questions as:
# - Reccomend me vegan options
# - Do you have spicy and gluten free dishes?
# - Where is the restaurant located?
# - How can i make reservations?

# %%
# !python platemate.py
# Out:
# Loading models...
# 1 docs indexed
# Models loaded. Ready to answer your questions.
#
# Ask your question (or type 'exit' to quit): do you have vegan options?
#
# Answer (azure): Yes, the menu at La Bella Vita includes several vegan options:
#
# - **Antipasti (Starters)**:
#   - Bruschetta al Pomodoro – $8.00 (Contains gluten)
#   - Arancini (Rice Balls) – $9.00 (Contains gluten, dairy, and eggs)
#
# - **Zuppe (Soups)**:
#   - Minestrone (Vegan) – $7.50 (Contains gluten)
#
# - **Pasta**:
#   - Spaghetti Aglio e Olio (Vegan) – $13.50 (Contains gluten)
#   - Lasagna Verde (Vegetarian) – $17.50 (Contains gluten, dairy, eggs)
#
# - **Pizza**:
#   - Vegana Pizza (Vegan) – $14.00 (Contains gluten)
#
# - **Daily Specials**:
#   - Vegan Pesto Risotto (Monday Special) – $15.00 (Contains nuts)
#   - Vegan Stuffed Bell Peppers (Thursday Special) – $14.50 (No allergens)
#
# Additionally, the restaurant offers a Vegan Chocolate Cake for dessert – $7.50 (Contains nuts) .
#
# ...
